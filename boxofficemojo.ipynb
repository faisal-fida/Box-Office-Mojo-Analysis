# %%
import pandas as pd

# %%
df = pd.read_excel('boxofficemojo.xlsx')

# %%
df.columns = df.columns.str.strip().str.lower()

df = df[["name", "worldwide", "year"]]

# %%
df['worldwide_normalized'] = 1 - (df['worldwide'] - df['worldwide'].min()) / (df['worldwide'].max() - df['worldwide'].min())
df['year_normalized'] = (df['year'] - df['year'].min()) / (df['year'].max() - df['year'].min())

# %%
df['combined_score'] = df['worldwide_normalized'] + df['year_normalized']

sorted_df = df.sort_values(by='combined_score', ascending=False)

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
fig = px.scatter(
    sorted_df,
    x="year",
    y="worldwide",
    color="combined_score",
    title="Worldwide Box Office vs. Year with Combined Score",
    labels={
        "worldwide": "Worldwide Box Office",
        "year": "Year",
        "combined_score": "Combined Score",
    },
    hover_data=["name"],
    color_continuous_scale=px.colors.sequential.Viridis,
)
fig.update_layout(
    xaxis=dict(showgrid=True, gridcolor="lightgray"),
    yaxis=dict(showgrid=True, gridcolor="lightgray"),
    plot_bgcolor="white",
    font=dict(family="Arial", size=12, color="black"),
    legend=dict(title="Combined Score", yanchor="top", y=0.99, xanchor="left", x=0.01),
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a158fc69-a2d2-4c91-a3d4-09c4a679abd3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a158fc69-a2d2-4c91-a3d4-09c4a679abd3")) {                    Plotly.newPlot(                        "a158fc69-a2d2-4c91-a3d4-09c4a679abd3",                        [{"customdata":[["IF"],["Ghostbusters: Frozen Empire"],["Insidious: The Red Door"],["The Equalizer 3"],["PAW Patrol: The Mighty Movie"],["The Marvels"],["Dungeons & Dragons: Honor Among Thieves"],["Trolls Band Together"],["Anyone But You"],["Napoleon"],["The Lost City"],["The Garfield Movie"],["A Quiet Place: Day One"],["DC League of Super-Pets"],["Nice View"],["Too Cool to Kill"],["Smile"],["Sound of Freedom"],["Wish"],["It Ends with Us"],["Lightyear"],["Chinese Doctors"],["Alien: Romulus"],["Taylor Swift: The Eras Tour"],["Ghostbusters: Afterlife"],["Raging Fire"],["The Conjuring: The Devil Made Me Do It"],["The Nun II"],["Bullet Train"],["The Flash"],["Creed III"],["The Bad Guys"],["Jungle Cruise"],["My Country, My Parents"],["Five Nights at Freddy's"],["Shock Wave 2"],["Cruella"],["Migration"],["Birds of Prey"],["The Croods: A New Age"],["A Little Red Flower"],["The White Storm 2: Drug Lords"],["Abominable"],["Sheep Without a Shepherd"],["Weathering with You"],["Encanto"],["Elvis"],["Downton Abbey"],["Rocketman"],["The Lego Movie 2: The Second Part"],["The Addams Family"],["Twisters"],["Jiang Ziya"],["Little Women"],["Project Gutenberg"],["Dolittle"],["The Equalizer 2"],["The Hunger Games: The Ballad of Songbirds & Snakes"],["Ford v Ferrari"],["Better Days"],["Christopher Robin"],["The Island"],["Annabelle Comes Home"],["A Quiet Place Part II"],["Kingdom of the Planet of the Apes"],["Us and Them"],["The Bravest"],["Creed II"],["Bad Boys: Ride or Die"],["Glass"],["Pitch Perfect 3"],["Smallfoot"],["X-Men: Dark Phoenix"],["Men in Black: International"],["Pegasus"],["Us"],["The Post"],["Indiana Jones and the Dial of Destiny"],["The Shape of Water"],["Smurfs: The Lost Village"],["Terminator: Dark Fate"],["Parasite"],["A Dog's Purpose"],["Free Guy"],["Crazy Rich Asians"],["Meg 2: The Trench"],["Storks"],["Bad Moms"],["The Emoji Movie"],["Geostorm"],["The Monkey King 2"],["Sonic the Hedgehog"],["Valerian and the City of a Thousand Planets"],["The BFG"],["Baby Driver"],["Youth"],["Paddington 2"],["Halloween"],["Arrival"],["Black Adam"],["London Has Fallen"],["Me Before You"],["Alien: Covenant"],["Bridget Jones's Baby"],["Tomb Raider"],["Aquaman and the Lost Kingdom"],["Jupiter Ascending"],["Journey to the West: The Demons Strike Back"],["Sonic the Hedgehog 2"],["Central Intelligence"],["Uncharted"],["Fantastic Beasts: The Secrets of Dumbledore"],["Jian Bing Man"],["Knives Out"],["Transformers: Rise of the Beasts"],["John Wick: Chapter 4"],["Inferno"],["Black Widow"],["Baahubali 2: The Conclusion"],["Maze Runner: The Death Cure"],["The Intern"],["Kung Fu Yoga"],["Pacific Rim: Uprising"],["Ghostbusters"],["Crazy Alien"],["Straight Outta Compton"],["John Wick: Chapter 3 - Parabellum"],["Ocean's Eight"],["Everest"],["Hidden Figures"],["Tenet"],["Tomorrowland"],["Assassin's Creed"],["Skyscraper"],["Sully"],["Eternals"],["Blade Runner 2049"],["Teenage Mutant Ninja Turtles: Out of the Shadows"],["Split"],["Ted 2"],["Ode to My Father"],["Dune: Part One"],["Sing 2"],["Breakup Buddies"],["The Equalizer"],["Ant-Man and the Wasp: Quantumania"],["Get Out"],["Green Book"],["Dumbo"],["Goodbye Mr. Loser"],["The Other Woman"],["Ferdinand"],["Need for Speed"],["Alvin and the Chipmunks: The Road Chip"],["Spy"],["Moon Man"],["Shazam!"],["Daddy's Home"],["Shang-Chi and the Legend of the Ten Rings"],["Fury"],["Annabelle: Creation"],["Into the Woods"],["Elemental"],["The Ex-File 3: Return of the Exes" ...

# %%
top_10 = sorted_df.sort_values(by="worldwide", ascending=False).head(10)
fig = px.bar(
    top_10,
    x="name",
    y="worldwide",
    title="Top 10 Movies by Worldwide Box Office",
    labels={"name": "Movie Name", "worldwide": "Worldwide Box Office"},
    color="combined_score",
    color_continuous_scale=px.colors.sequential.Plasma,
)

fig.update_layout(
    xaxis=dict(tickangle=-45, showgrid=True, gridcolor="lightgray"),
    yaxis=dict(showgrid=True, gridcolor="lightgray"),
    plot_bgcolor="white",
    font=dict(family="Arial", size=12, color="black"),
    legend=dict(title="Combined Score", yanchor="top", y=0.99, xanchor="left", x=0.01),
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="73ee0237-0843-4fed-8077-71aaf17dae43" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73ee0237-0843-4fed-8077-71aaf17dae43")) {                    Plotly.newPlot(                        "73ee0237-0843-4fed-8077-71aaf17dae43",                        [{"alignmentgroup":"True","hovertemplate":"Movie Name=%{x}\u003cbr\u003eWorldwide Box Office=%{y}\u003cbr\u003ecombined_score=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[0.8275862068965517,0.9878831938396999,1.1972584195424552,0.9301581206062498,1.2076558231497456,1.249034870540619,1.3293278706194132,1.3535633317243583,1.4580186164330973,1.403013683911364],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Avatar","Avengers: Endgame","Avatar: The Way of Water","Titanic","Star Wars: Episode VII - The Force Awakens","Avengers: Infinity War","Spider-Man: No Way Home","Jurassic World","Inside Out 2","The Lion King"],"xaxis":"x","y":[2923706026,2799439100,2320250281,2264750694,2071310218,2052415039,1926899310,1671537444,1668778335,1662020819],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[ ...

# %%
bottom_10 = sorted_df.sort_values(by="combined_score", ascending=True).head(10)
fig = px.bar(
    bottom_10,
    x="combined_score",
    y="name",
    orientation="h",
    title="Bottom 10 Movies by Combined Score",
    labels={"combined_score": "Combined Score", "name": "Movie Name"},
    color="worldwide",
    color_continuous_scale=px.colors.sequential.Inferno,
)
fig.update_layout(
    xaxis=dict(showgrid=True, gridcolor="lightgray"),
    yaxis=dict(showgrid=True, gridcolor="lightgray"),
    plot_bgcolor="white",
    font=dict(family="Arial", size=12, color="black"),
    legend=dict(
        title="Worldwide Box Office", yanchor="top", y=0.99, xanchor="left", x=0.01
    ),
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3376c004-0fd5-4a50-8a50-561174e4abd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3376c004-0fd5-4a50-8a50-561174e4abd7")) {                    Plotly.newPlot(                        "3376c004-0fd5-4a50-8a50-561174e4abd7",                        [{"alignmentgroup":"True","hovertemplate":"Combined Score=%{x}\u003cbr\u003eMovie Name=%{y}\u003cbr\u003eworldwide=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[2923706026,2264750694,402382193,2799439100,184960747,267447150,2320250281,2071310218,775398507,2052415039],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[0.8275862068965517,0.9301581206062498,0.9432114491505272,0.9878831938396999,0.9995765751656019,1.0269422737326528,1.1972584195424552,1.2076558231497456,1.2438510182343503,1.249034870540619],"xaxis":"x","y":["Avatar","Titanic","Gone with the Wind","Avengers: Endgame","Snow White and the Seven Dwarfs","Bambi","Avatar: The Way of Water","Star Wars: Episode VII - The Force Awakens","Star Wars: Episode IV - A New Hope","Avengers: Infinity War"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}] ...
